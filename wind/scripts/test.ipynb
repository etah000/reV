# %%
import h5py
with h5py.File(r"D:\opensource\reV\tests\data\wtk\ri_100_wtk_2012.h5","r") as f:
    print(f['meta'].dtype.names)      # 列名，查找 'gid'/'lat'/'lon'
    # 若是复合 dtype，可以取部分查看
# Out:
# ('latitude', 'longitude', 'country', 'state', 'county', 'timezone', 'elevation', 'offshore')

# %%
from reV import TESTDATADIR
print(TESTDATADIR)
# Out:
# D:\miniconda3\envs\rev-test\Lib\site-packages\tests\data
